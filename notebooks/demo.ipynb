// %% [markdown]
// # Demo For the GoWorkshop

// %% [markdown]
// ## Linear Regression

// %% [markdown]
// ### first we need to load the data
// For this we will be using dataframe-go Library

// %%
import (
	"context"
	"fmt"
	"io/ioutil"
	"log"
	"strings"
	"github.com/rocketlaunchr/dataframe-go"
	"github.com/rocketlaunchr/dataframe-go/imports"
)

var ctx = context.Background()

func loadGopherData() *dataframe.DataFrame {
	content, err := ioutil.ReadFile("gopher_locations.csv")
	if err != nil {
		log.Fatal(err)
	}

	// Convert the content to a string
	csvString := string(content)
	df, err := imports.LoadFromCSV(ctx, strings.NewReader(csvString), imports.CSVLoadOptions{InferDataTypes: true, NilValue: &[]string{"NA"}[0]})
	if err != nil {
		panic(err)
	}

	return df
}

var df = loadGopherData()

// %%
func displayTheData(df *dataframe.DataFrame) {
 // Print the DataFrame
 fmt.Print(df.Table())
}

// %%
func main(){
    displayTheData(df)
	//Get the number of rows in the DataFrame
	numRows := df.NRows()

	// Get the first column by index
	X := df.Series[0]

	// Print the values of the first column
	for i := 0; i < int(numRows); i++ {
		value := X.Value(i)
		fmt.Println(value)
	}
}
// Out:
// +-------+----------------------+--------------------+-----------------+------------------+--------------+---------------+------------+----------+
// |       |     LOCATIONNAME     | AVERAGETEMPERATURE | PREDATORDENSITY | FOODAVAILABILITY | WATERSOURCES | HUMANACTIVITY | VEGETATION | LANDAREA |
// +-------+----------------------+--------------------+-----------------+------------------+--------------+---------------+------------+----------+
// |  0:   |     Quiet Spring     |        -4.5        |     medium      |      medium      |     far      |     high      |   cliff    |   669    |
// |  1:   |     Sunny Forest     |         23         |       low       |      medium      |     far      |   moderate    |   meadow   |   332    |
// |  2:   |     Misty Dunes      |        38.8        |     medium      |       low        |     far      |     high      |   forest   |   942    |
// |  3:   |    Bright Spring     |         23         |      high       |       high       |    close     |   moderate    |   desert   |   973    |
// |  4:   |     Blue Spring      |        7.4         |       low       |      medium      |     far      |   moderate    |   desert   |   768    |
// |  5:   |     Shady Glade      |        32.4        |      high       |      medium      |    close     |     high      |   urban    |   566    |
// |  6:   |      Blue Lake       |        34.6        |       low       |       high       |    close     |   moderate    |   cliff    |   517    |
// |  7:   |     Gopher Lake      |        24.1        |     medium      |       high       |     far      |      low      |   cliff    |   461    |
// |  8:   |     Windy Fields     |        -4.7        |      high       |       low        |     far      |   moderate    |   meadow   |   261    |
// |  9:   |    Bustling Dunes    |        4.6         |       low       |      medium      |     far      |     high      |   meadow   |   604    |
// |  10:  |    Lonely Fields     |        -2.9        |       low       |       low        |     far      |     high      |   urban    |   242    |
// |  11:  |     Gopher Dunes     |         25         |      high       |      medium      |    close     |     high      |   meadow   |   502    |
// |  12:  |     Noisy Island     |        31.7        |       low       |      medium      |    close     |      low      |   meadow   |   524    |
// |  13:  |      Dark Creek      |        35.1        |       low       |      medium      |    close     |      low      |   desert   |   941    |
// |  14:  |    Misty Prairie     |        27.7        |       low       |       low        |     far      |      low      |   urban    |   380    |
// |  15:  |      Warm Pond       |        19.9        |      high       |      medium      |     far      |   moderate    |   forest   |   533    |
// |  16:  |     Sunny Meadow     |        12.5        |     medium      |      medium      |     far      |      low      |   forest   |   226    |
// |  17:  |    Noisy Prairie     |        14.4        |     medium      |       high       |     far      |     high      |   urban    |   171    |
// |  18:  |   Peaceful Spring    |         24         |       low       |       low        |    close     |   moderate    |   urban    |   674    |
// |  19:  |     Shady Island     |        20.2        |      high       |       low        |     far      |      low      |   forest   |   667    |
// |  20:  |      Sunny Park      |        38.5        |      high       |       low        |    close     |     high      |   urban    |   344    |
// |  21:  |     Cool Valley      |        24.4        |     medium      |       low        |     far      |     high      |   desert   |   259    |
// |  22:  |       Dark Bay       |        33.5        |       low       |       high       |    close     |   moderate    |   cliff    |   926    |
// |  23:  |    Gopher Fields     |        34.1        |      high       |       low        |     far      |      low      |   urban    |   234    |
// |  24:  |    Bustling Cove     |        6.2         |     medium      |       low        |    close     |   moderate    |   meadow   |   395    |
// |  25:  |     Silver Glade     |        31.3        |      high       |       low        |     far      |      low      |   forest   |   793    |
// |  26:  |    Bright Cliffs     |         6          |       low       |       low        |    close     |      low      |   urban    |   683    |
// |  27:  |     Hidden Cove      |        35.2        |      high       |       high       |     far      |   moderate    |   forest   |   702    |
// |  28:  |    Hidden Island     |        3.3         |       low       |       low        |    close     |     high      |   urban    |   774    |
// |  29:  |     Misty River      |        22.2        |       low       |       high       |    close     |      low      |   urban    |   209    |
// |  30:  |      Warm Dunes      |        9.1         |       low       |       low        |    close     |      low      |   urban    |   180    |
// |  31:  |     Gopher Park      |        20.1        |     medium      |       low        |     far      |     high      |   urban    |   304    |
// |  32:  |     Bright Dunes     |         10         |      high       |       high       |    close     |     high      |   urban    |   256    |
// |  33:  |     Cool Forest      |        29.4        |      high       |       high       |    close     |     high      |   cliff    |   988    |
// |  34:  |     Golden Glade     |        25.2        |      high       |       low        |     far      |      low      |   forest   |   784    |
// |  35:  |     Lonely Grove     |        11.2        |       low       |      medium      |     far      |   moderate    |   desert   |   700    |
// |  36:  |   Peaceful Fields    |        21.2        |      high       |       low        |     far      |   moderate    |   forest   |   405    |
// |  37:  |     Noisy River      |        12.8        |       low       |      medium      |    close     |     high      |   meadow   |   691    |
// |  38:  |      Noisy Cove      |         21         |     medium      |       low        |    close     |   moderate    |   urban    |   762    |
// |  39:  |     Misty Forest     |        9.9         |     medium      |       low        |     far      |      low      |   desert   |   815    |
// |  40:  |     Shady Cliffs     |        -3.5        |       low       |       high       |    close     |     high      |   meadow   |   630    |
// |  41:  |     Misty Fields     |        13.3        |     medium      |      medium      |     far      |   moderate    |   meadow   |   190    |
// |  42:  |     Windy Hills      |        36.2        |     medium      |      medium      |     far      |     high      |   desert   |   926    |
// |  43:  |     Lonely Creek     |        4.4         |      high       |       high       |    close     |      low      |   cliff    |   451    |
// |  44:  |     Windy River      |        12.7        |      high       |       high       |     far      |     high      |   cliff    |   790    |
// |  45:  |     Silver Grove     |        38.1        |      high       |       high       |    close     |      low      |   meadow   |   497    |
// |  46:  |      Misty Park      |        24.1        |      high       |      medium      |     far      |   moderate    |   meadow   |   744    |
// |  47:  |    Bright Meadow     |        -2.5        |       low       |      medium      |    close     |   moderate    |   meadow   |   630    |
// |  48:  |      Windy Lake      |        -0.6        |      high       |       low        |     far      |   moderate    |   meadow   |   344    |
// |  49:  |     Quiet Creek      |        22.8        |     medium      |       high       |    close     |   moderate    |   meadow   |   315    |
// |  50:  |    Bustling Glade    |        12.6        |      high       |       high       |    close     |   moderate    |   meadow   |   669    |
// |  51:  |     Windy Island     |        15.8        |       low       |       low        |     far      |   moderate    |   desert   |   954    |
// |  52:  |     Dark Valley      |        15.8        |     medium      |       high       |     far      |     high      |   desert   |   774    |
// |  53:  |      Dark Park       |        12.1        |       low       |      medium      |    close     |   moderate    |   desert   |   842    |
// |  54:  |      Silver Bay      |        -8.2        |      high       |       low        |     far      |   moderate    |   meadow   |   372    |
// |  55:  |      Misty Cove      |        38.2        |      high       |      medium      |    close     |      low      |   desert   |   503    |
// |  56:  |     Quiet Haven      |        -6.1        |      high       |       low        |     far      |   moderate    |   meadow   |   488    |
// |  57:  |     Noisy Meadow     |        -5.7        |     medium      |       high       |    close     |   moderate    |   desert   |   369    |
// |  58:  |    Bright Fields     |        35.8        |      high       |      medium      |    close     |     high      |   cliff    |   988    |
// |  59:  |     Noisy Creek      |        2.2         |     medium      |      medium      |     far      |   moderate    |   cliff    |   287    |
// |  60:  |      Dark Haven      |         20         |       low       |      medium      |    close     |     high      |   meadow   |   414    |
// |  61:  |      Happy Lake      |         8          |      high       |       high       |    close     |   moderate    |   forest   |   921    |
// |  62:  |     Windy Valley     |        21.7        |     medium      |       low        |     far      |   moderate    |   desert   |   807    |
// |  63:  |     Quiet Glade      |        -1.1        |      high       |       high       |     far      |     high      |   forest   |   129    |
// |  64:  |     Golden Cove      |         -1         |       low       |      medium      |     far      |     high      |   desert   |   875    |
// |  65:  |      Warm Hills      |        0.8         |     medium      |      medium      |     far      |      low      |   meadow   |   611    |
// |  66:  |   Peaceful Meadow    |        11.3        |     medium      |       low        |    close     |     high      |   urban    |   119    |
// |  67:  |    Sunny Prairie     |        27.8        |       low       |      medium      |     far      |     high      |   forest   |   453    |
// |  68:  |      Warm Creek      |        20.8        |      high       |      medium      |    close     |      low      |   urban    |   570    |
// |  69:  |     Windy Spring     |        33.9        |     medium      |       high       |     far      |     high      |   desert   |   423    |
// |  70:  |      Green Pond      |        -8.4        |      high       |       high       |    close     |      low      |   cliff    |   850    |
// |  71:  |     Hidden Glade     |        6.2         |       low       |      medium      |    close     |      low      |   cliff    |   149    |
// |  72:  |     Windy Dunes      |        24.8        |     medium      |      medium      |    close     |     high      |   urban    |   518    |
// |  73:  |     Silver River     |        27.6        |       low       |       low        |     far      |     high      |   urban    |   898    |
// |  74:  |     Happy Hills      |        36.8        |       low       |      medium      |    close     |     high      |   urban    |   692    |
// |  75:  |      Happy Park      |        38.6        |      high       |      medium      |     far      |      low      |   desert   |   369    |
// |  76:  |      Lonely Bay      |        -3.9        |       low       |       high       |    close     |      low      |   desert   |   338    |
// |  77:  |    Hidden Spring     |        2.1         |      high       |       low        |     far      |   moderate    |   cliff    |   294    |
// |  78:  |    Hidden Valley     |        1.4         |      high       |      medium      |     far      |     high      |   forest   |   873    |
// |  79:  |     Golden Pond      |        24.3        |     medium      |       low        |    close     |      low      |   meadow   |   731    |
// |  80:  |    Peaceful Haven    |        18.8        |       low       |      medium      |    close     |   moderate    |   cliff    |   287    |
// |  81:  |    Silver Spring     |        -7.7        |     medium      |       high       |    close     |     high      |   cliff    |   152    |
// |  82:  |    Windy Prairie     |        11.8        |       low       |       high       |     far      |     high      |   urban    |   590    |
// |  83:  |     Gopher Grove     |        24.1        |     medium      |      medium      |     far      |     high      |   cliff    |   178    |
// |  84:  |     Hidden Hills     |        23.5        |     medium      |       high       |     far      |     high      |   desert   |   984    |
// |  85:  |     Quiet Fields     |        8.4         |      high       |      medium      |    close     |     high      |   forest   |   150    |
// |  86:  |      Cool Creek      |        1.6         |       low       |       low        |     far      |     high      |   forest   |   389    |
// |  87:  |    Peaceful Pond     |        12.2        |      high       |       low        |     far      |     high      |   forest   |   227    |
// |  88:  |     Cool Spring      |        21.1        |      high       |      medium      |    close     |     high      |   forest   |   638    |
// |  89:  |     Gopher Hills     |        31.5        |       low       |       high       |     far      |      low      |   cliff    |   768    |
// |  90:  |     Shady Spring     |        21.7        |     medium      |      medium      |     far      |   moderate    |   cliff    |   585    |
// |  91:  |     Windy Forest     |        12.6        |       low       |       low        |    close     |   moderate    |   urban    |   827    |
// |  92:  |    Silver Cliffs     |        28.2        |     medium      |       low        |     far      |      low      |   forest   |   623    |
// |  93:  |    Bright Forest     |        34.1        |     medium      |      medium      |     far      |     high      |   forest   |   610    |
// |  94:  |     Warm Forest      |        -4.4        |       low       |       high       |    close     |   moderate    |   desert   |   976    |
// |  95:  |     Golden Hills     |        13.5        |      high       |       low        |     far      |     high      |   urban    |   369    |
// |  96:  |    Gopher Cliffs     |         5          |     medium      |       high       |    close     |   moderate    |   meadow   |   672    |
// |  97:  |      Shady Park      |        0.3         |     medium      |      medium      |     far      |      low      |   desert   |   788    |
// |  98:  |      Blue River      |         14         |      high       |       high       |     far      |     high      |   urban    |   538    |
// |  99:  |     Noisy Hills      |         26         |       low       |       low        |    close     |      low      |   meadow   |   298    |
// | 100:  |     Misty Island     |        12.5        |       low       |       high       |    close     |     high      |   cliff    |   550    |
// | 101:  |     Noisy Cliffs     |        8.6         |       low       |       high       |     far      |   moderate    |   desert   |   700    |
// | 102:  |     Noisy Haven      |        23.1        |     medium      |       high       |     far      |   moderate    |   forest   |   674    |
// | 103:  |    Peaceful Park     |        -1.6        |      high       |       low        |     far      |   moderate    |   cliff    |   549    |
// | 104:  |      Blue Pond       |        2.8         |     medium      |       low        |    close     |     high      |   cliff    |   391    |
// | 105:  |      Warm Haven      |        39.6        |      high       |      medium      |     far      |     high      |   desert   |   240    |
// | 106:  |     Misty Haven      |        12.6        |       low       |       low        |    close     |     high      |   forest   |   186    |
// | 107:  |     Dark Spring      |        15.4        |     medium      |      medium      |     far      |   moderate    |   urban    |   833    |
// | 108:  |      Windy Cove      |         3          |     medium      |       low        |    close     |     high      |   meadow   |   194    |
// | 109:  |    Bright Island     |        15.6        |       low       |       low        |     far      |   moderate    |   urban    |   951    |
// | 110:  |     Gopher Cove      |        9.4         |      high       |      medium      |    close     |      low      |   forest   |   733    |
// | 111:  |      Warm River      |        20.5        |      high       |       low        |     far      |     high      |   urban    |   811    |
// | 112:  |     Green Meadow     |        12.1        |      high       |      medium      |    close     |     high      |   urban    |   312    |
// | 113:  |      Cool Pond       |        -1.1        |     medium      |       high       |     far      |      low      |   urban    |   970    |
// | 114:  |    Hidden Prairie    |        7.9         |       low       |       low        |     far      |     high      |   meadow   |   675    |
// | 115:  |      Cool River      |        23.5        |     medium      |      medium      |    close     |      low      |   urban    |   691    |
// | 116:  |     Shady Hills      |        1.5         |      high       |       high       |    close     |     high      |   desert   |   405    |
// | 117:  |      Blue Haven      |        26.7        |      high       |      medium      |     far      |     high      |   forest   |   465    |
// | 118:  |      Dark Pond       |        12.8        |       low       |      medium      |     far      |     high      |   desert   |   940    |
// | 119:  |     Silver Lake      |         6          |      high       |       low        |    close     |      low      |   meadow   |   448    |
// | 120:  |     Dark Cliffs      |        -2.8        |      high       |       low        |     far      |   moderate    |   meadow   |   457    |
// | 121:  |     Blue Cliffs      |        38.8        |      high       |       low        |     far      |      low      |   urban    |   353    |
// | 122:  |     Silver Dunes     |        28.4        |     medium      |       low        |    close     |   moderate    |   urban    |   301    |
// | 123:  |    Peaceful River    |        -3.8        |      high       |       low        |     far      |     high      |   cliff    |   280    |
// | 124:  |     Green Glade      |        18.3        |     medium      |       high       |    close     |     high      |   urban    |   830    |
// | 125:  |    Peaceful Lake     |        7.8         |       low       |       high       |     far      |      low      |   meadow   |   927    |
// | 126:  |     Green River      |         31         |       low       |       high       |     far      |      low      |   urban    |   408    |
// | 127:  |      Cool Hills      |        -0.2        |       low       |       high       |     far      |   moderate    |   desert   |   171    |
// | 128:  |     Misty Hills      |        23.5        |       low       |       low        |    close     |      low      |   meadow   |   313    |
// | 129:  |     Windy Glade      |        4.7         |     medium      |      medium      |     far      |     high      |   meadow   |   884    |
// | 130:  |      Blue Cove       |        25.8        |     medium      |      medium      |     far      |     high      |   meadow   |   207    |
// | 131:  |     Hidden River     |        26.4        |       low       |       low        |    close     |   moderate    |   cliff    |   961    |
// | 132:  |    Lonely Valley     |        -3.9        |       low       |       low        |     far      |   moderate    |   desert   |   312    |
// | 133:  |     Sunny Dunes      |        8.9         |     medium      |      medium      |    close     |      low      |   urban    |   773    |
// | 134:  |     Sunny Fields     |        26.9        |       low       |       high       |    close     |      low      |   meadow   |   943    |
// | 135:  |      Golden Bay      |        1.7         |       low       |      medium      |    close     |      low      |   forest   |   421    |
// | 136:  |     Misty Glade      |        -3.3        |       low       |       low        |    close     |     high      |   urban    |   878    |
// | 137:  |     Blue Island      |        10.9        |      high       |       high       |    close     |      low      |   urban    |   600    |
// | 138:  |     Silver Creek     |        15.5        |      high       |       low        |    close     |      low      |   desert   |   205    |
// | 139:  |      Gopher Bay      |        27.7        |      high       |       low        |    close     |      low      |   urban    |   776    |
// | 140:  |       Cool Bay       |        28.1        |       low       |       high       |     far      |   moderate    |   desert   |   492    |
// | 141:  |    Bustling Hills    |        0.2         |       low       |       high       |     far      |   moderate    |   meadow   |   760    |
// | 142:  |   Bustling Valley    |        15.6        |      high       |       low        |    close     |     high      |   forest   |   960    |
// | 143:  |     Noisy Glade      |        32.7        |     medium      |       high       |    close     |     high      |   desert   |   700    |
// | 144:  |      Green Cove      |        9.7         |       low       |       low        |    close     |      low      |   meadow   |   257    |
// | 145:  |     Hidden Dunes     |         23         |       low       |      medium      |    close     |      low      |   urban    |   937    |
// | 146:  |   Bustling Spring    |        35.6        |      high       |       high       |    close     |   moderate    |   urban    |   147    |
// | 147:  |    Silver Fields     |        32.6        |     medium      |       low        |     far      |   moderate    |   forest   |   500    |
// | 148:  |     Sunny Cliffs     |         35         |     medium      |       low        |    close     |      low      |   cliff    |   799    |
// | 149:  |     Gopher Haven     |        2.6         |       low       |       low        |     far      |      low      |   cliff    |   990    |
// | 150:  |    Golden Valley     |         22         |       low       |       high       |     far      |      low      |   cliff    |   124    |
// | 151:  |      Dark River      |        -0.9        |     medium      |       high       |     far      |     high      |   urban    |   310    |
// | 152:  |     Golden Lake      |        39.6        |       low       |      medium      |    close     |     high      |   meadow   |   454    |
// | 153:  |     Bright Hills     |        6.3         |       low       |      medium      |    close     |      low      |   forest   |   259    |
// | 154:  |     Silver Pond      |        15.6        |     medium      |      medium      |     far      |   moderate    |   cliff    |   947    |
// | 155:  |    Peaceful Dunes    |         39         |      high       |       high       |     far      |      low      |   cliff    |   414    |
// | 156:  |     Sunny Island     |        -6.6        |       low       |       high       |    close     |   moderate    |   cliff    |   873    |
// | 157:  |     Lonely Glade     |        20.5        |      high       |       high       |    close     |     high      |   urban    |   322    |
// | 158:  |     Happy Island     |        -5.9        |     medium      |      medium      |     far      |   moderate    |   desert   |   982    |
// | 159:  |     Peaceful Bay     |        15.1        |      high       |       high       |    close     |   moderate    |   forest   |   428    |
// | 160:  |      Shady Lake      |        35.5        |       low       |       high       |     far      |      low      |   urban    |   445    |
// | 161:  |     Blue Forest      |        24.1        |       low       |       high       |    close     |   moderate    |   forest   |   627    |
// | 162:  |   Bustling Cliffs    |        38.6        |       low       |       high       |     far      |   moderate    |   desert   |   269    |
// | 163:  |      Green Lake      |        39.3        |       low       |       high       |     far      |     high      |   cliff    |   351    |
// | 164:  |      Happy Cove      |        10.2        |       low       |       high       |    close     |      low      |   urban    |   238    |
// | 165:  |     Bright Glade     |        33.7        |       low       |       high       |     far      |     high      |   meadow   |   363    |
// | 166:  |     Cool Meadow      |        4.2         |     medium      |       high       |    close     |     high      |   urban    |   623    |
// | 167:  |    Lonely Cliffs     |        24.5        |     medium      |       low        |    close     |      low      |   desert   |   422    |
// | 168:  |     Cool Cliffs      |        25.5        |      high       |      medium      |     far      |     high      |   desert   |   272    |
// | 169:  |     Gopher Glade     |        28.2        |     medium      |       low        |    close     |     high      |   forest   |   548    |
// | 170:  |     Lonely Cove      |        8.6         |       low       |       high       |    close     |      low      |   urban    |   823    |
// | 171:  |      Dark Glade      |        18.9        |       low       |       high       |    close     |      low      |   urban    |   845    |
// | 172:  |      Sunny Bay       |        16.8        |       low       |       low        |    close     |   moderate    |   forest   |   836    |
// | 173:  |     Green Creek      |        -5.7        |      high       |      medium      |     far      |   moderate    |   cliff    |   174    |
// | 174:  |     Silver Cove      |        38.7        |       low       |       low        |    close     |      low      |   urban    |   725    |
// | 175:  |     Warm Meadow      |        -1.1        |       low       |       low        |    close     |     high      |   cliff    |   257    |
// | 176:  |      Dark Lake       |        37.7        |       low       |       high       |    close     |   moderate    |   urban    |   480    |
// | 177:  |     Bustling Bay     |         4          |     medium      |       low        |     far      |   moderate    |   desert   |   370    |
// | 178:  |   Bustling Island    |        6.2         |       low       |       low        |     far      |     high      |   forest   |   106    |
// | 179:  |     Shady Valley     |        33.8        |     medium      |      medium      |    close     |      low      |   desert   |   1000   |
// | 180:  |     Green Fields     |         -7         |       low       |       high       |     far      |     high      |   desert   |   107    |
// | 181:  |      Misty Lake      |        37.3        |       low       |       low        |     far      |     high      |   desert   |   174    |
// | 182:  |      Cool Cove       |        39.2        |       low       |       low        |     far      |      low      |   desert   |   872    |
// | 183:  |     Noisy Forest     |        20.9        |     medium      |      medium      |     far      |      low      |   forest   |   462    |
// | 184:  |     Cool Fields      |        33.7        |      high       |       high       |    close     |     high      |   forest   |   963    |
// | 185:  |     Golden Creek     |        15.4        |      high       |       low        |     far      |   moderate    |   meadow   |   218    |
// | 186:  |      Misty Bay       |        -7.9        |     medium      |       high       |    close     |     high      |   desert   |   237    |
// | 187:  |    Quiet Prairie     |        10.9        |      high       |       high       |     far      |     high      |   cliff    |   778    |
// | 188:  |      Quiet Bay       |        16.4        |      high       |       low        |     far      |     high      |   meadow   |   163    |
// | 189:  |    Gopher Meadow     |        5.3         |      high       |       high       |     far      |      low      |   meadow   |   181    |
// | 190:  |     Dark Prairie     |        5.4         |     medium      |      medium      |     far      |   moderate    |   meadow   |   170    |
// | 191:  |      Warm Cove       |        34.7        |     medium      |      medium      |     far      |      low      |   urban    |   604    |
// | 192:  |     Quiet Meadow     |        8.7         |       low       |      medium      |     far      |   moderate    |   cliff    |   461    |
// | 193:  |     Quiet Hills      |        15.5        |     medium      |      medium      |     far      |     high      |   meadow   |   633    |
// | 194:  |     Windy Creek      |        33.9        |     medium      |       low        |     far      |     high      |   meadow   |   784    |
// | 195:  |     Sunny River      |        33.4        |       low       |       low        |     far      |   moderate    |   urban    |   433    |
// | 196:  |    Golden Spring     |        14.8        |     medium      |       high       |     far      |      low      |   meadow   |   989    |
// | 197:  |     Cool Island      |         10         |      high       |       high       |     far      |     high      |   cliff    |   103    |
// | 198:  |     Bright Creek     |        5.1         |     medium      |       low        |    close     |   moderate    |   meadow   |   461    |
// | 199:  |     Warm Valley      |        21.6        |     medium      |       low        |     far      |      low      |   cliff    |   355    |
// | 200:  | Ideal Gopher Habitat |         20         |       low       |       high       |    close     |      low      |   meadow   |   250    |
// +-------+----------------------+--------------------+-----------------+------------------+--------------+---------------+------------+----------+
// | 201X8 |        STRING        |      FLOAT64       |     STRING      |      STRING      |    STRING    |    STRING     |   STRING   |  INT64   |
// +-------+----------------------+--------------------+-----------------+------------------+--------------+---------------+------------+----------+
// Quiet Spring
// Sunny Forest
// Misty Dunes
// Bright Spring
// Blue Spring
// Shady Glade
// Blue Lake
// Gopher Lake
// Windy Fields
// Bustling Dunes
// Lonely Fields
// Gopher Dunes
// Noisy Island
// Dark Creek
// Misty Prairie
// Warm Pond
// Sunny Meadow
// Noisy Prairie
// Peaceful Spring
// Shady Island
// Sunny Park
// Cool Valley
// Dark Bay
// Gopher Fields
// Bustling Cove
// Silver Glade
// Bright Cliffs
// Hidden Cove
// Hidden Island
// Misty River
// Warm Dunes
// Gopher Park
// Bright Dunes
// Cool Forest
// Golden Glade
// Lonely Grove
// Peaceful Fields
// Noisy River
// Noisy Cove
// Misty Forest
// Shady Cliffs
// Misty Fields
// Windy Hills
// Lonely Creek
// Windy River
// Silver Grove
// Misty Park
// Bright Meadow
// Windy Lake
// Quiet Creek
// Bustling Glade
// Windy Island
// Dark Valley
// Dark Park
// Silver Bay
// Misty Cove
// Quiet Haven
// Noisy Meadow
// Bright Fields
// Noisy Creek
// Dark Haven
// Happy Lake
// Windy Valley
// Quiet Glade
// Golden Cove
// Warm Hills
// Peaceful Meadow
// Sunny Prairie
// Warm Creek
// Windy Spring
// Green Pond
// Hidden Glade
// Windy Dunes
// Silver River
// Happy Hills
// Happy Park
// Lonely Bay
// Hidden Spring
// Hidden Valley
// Golden Pond
// Peaceful Haven
// Silver Spring
// Windy Prairie
// Gopher Grove
// Hidden Hills
// Quiet Fields
// Cool Creek
// Peaceful Pond
// Cool Spring
// Gopher Hills
// Shady Spring
// Windy Forest
// Silver Cliffs
// Bright Forest
// Warm Forest
// Golden Hills
// Gopher Cliffs
// Shady Park
// Blue River
// Noisy Hills
// Misty Island
// Noisy Cliffs
// Noisy Haven
// Peaceful Park
// Blue Pond
// Warm Haven
// Misty Haven
// Dark Spring
// Windy Cove
// Bright Island
// Gopher Cove
// Warm River
// Green Meadow
// Cool Pond
// Hidden Prairie
// Cool River
// Shady Hills
// Blue Haven
// Dark Pond
// Silver Lake
// Dark Cliffs
// Blue Cliffs
// Silver Dunes
// Peaceful River
// Green Glade
// Peaceful Lake
// Green River
// Cool Hills
// Misty Hills
// Windy Glade
// Blue Cove
// Hidden River
// Lonely Valley
// Sunny Dunes
// Sunny Fields
// Golden Bay
// Misty Glade
// Blue Island
// Silver Creek
// Gopher Bay
// Cool Bay
// Bustling Hills
// Bustling Valley
// Noisy Glade
// Green Cove
// Hidden Dunes
// Bustling Spring
// Silver Fields
// Sunny Cliffs
// Gopher Haven
// Golden Valley
// Dark River
// Golden Lake
// Bright Hills
// Silver Pond
// Peaceful Dunes
// Sunny Island
// Lonely Glade
// Happy Island
// Peaceful Bay
// Shady Lake
// Blue Forest
// Bustling Cliffs
// Green Lake
// Happy Cove
// Bright Glade
// Cool Meadow
// Lonely Cliffs
// Cool Cliffs
// Gopher Glade
// Lonely Cove
// Dark Glade
// Sunny Bay
// Green Creek
// Silver Cove
// Warm Meadow
// Dark Lake
// Bustling Bay
// Bustling Island
// Shady Valley
// Green Fields
// Misty Lake
// Cool Cove
// Noisy Forest
// Cool Fields
// Golden Creek
// Misty Bay
// Quiet Prairie
// Quiet Bay
// Gopher Meadow
// Dark Prairie
// Warm Cove
// Quiet Meadow
// Quiet Hills
// Windy Creek
// Sunny River
// Golden Spring
// Cool Island
// Bright Creek
// Warm Valley
// Ideal Gopher Habitat

// %%
import (
	"context"
	"fmt"
	"io/ioutil"
	"log"
	"strconv"
	"strings"
	"github.com/gonum/stat"
	"gonum.org/v1/gonum/mat"
	"github.com/rocketlaunchr/dataframe-go"
	"github.com/rocketlaunchr/dataframe-go/imports"
)


func main() {

	// Extract the columns
	averageTemperature := df.Series[1]
	predatorDensity := df.Series[2]
	foodAvailability := df.Series[3]
	waterSources := df.Series[4]
	humanActivity := df.Series[5]
	vegetation := df.Series[6]
	landArea := df.Series[7]

	// Prepare X and y
	// For this example, let's use AverageTemperature as the target (y)
	// and PredatorDensity, FoodAvailability, WaterSources, HumanActivity, Vegetation, and LandArea as features (X)
	var X [][]float64
	var y []float64

	numRows := df.NRows()

	for i := 0; i < int(numRows); i++ {
		row := []float64{}

		// Convert categorical variables to numerical (simplified encoding)
		predatorDensityValue := map[string]float64{"low": 1, "medium": 2, "high": 3}[fmt.Sprintf("%v", predatorDensity.Value(i))]
		foodAvailabilityValue := map[string]float64{"low": 1, "medium": 2, "high": 3}[fmt.Sprintf("%v", foodAvailability.Value(i))]
		waterSourcesValue := map[string]float64{"near": 1, "medium": 2, "far": 3}[fmt.Sprintf("%v", waterSources.Value(i))]
		humanActivityValue := map[string]float64{"low": 1, "medium": 2, "high": 3}[fmt.Sprintf("%v", humanActivity.Value(i))]
		vegetationValue := map[string]float64{"forest": 1, "cliff": 2, "grassland": 3}[fmt.Sprintf("%v", vegetation.Value(i))]

		landAreaValue, err := strconv.ParseFloat(fmt.Sprintf("%v", landArea.Value(i)), 64)
		if err != nil {
			log.Fatalf("Error converting LandArea to float64: %v", err)
		}

		row = append(row, predatorDensityValue, foodAvailabilityValue, waterSourcesValue, humanActivityValue, vegetationValue, landAreaValue)
		X = append(X, row)

		averageTemperatureValue, err := strconv.ParseFloat(fmt.Sprintf("%v", averageTemperature.Value(i)), 64)
		if err != nil {
			log.Fatalf("Error converting AverageTemperature to float64: %v", err)
		}
		y = append(y, averageTemperatureValue)
	}

	// Convert X and y to matrices for gonum
	nSamples, nFeatures := len(X), len(X[0])
	Xmat := mat.NewDense(nSamples, nFeatures, nil)
	for i := range X {
		for j := range X[i] {
			Xmat.Set(i, j, X[i][j])
		}
	}

	ymat := mat.NewVecDense(nSamples, y)

	// Add a column of ones to X for the intercept term
	XWithIntercept := mat.NewDense(nSamples, nFeatures+1, nil)
	for i := 0; i < nSamples; i++ {
		XWithIntercept.Set(i, 0, 1) // intercept term
		for j := 0; j < nFeatures; j++ {
			XWithIntercept.Set(i, j+1, Xmat.At(i, j))
		}
	}

	// Compute (X^T * X)
	var XT mat.Dense
	XT.Mul(XWithIntercept.T(), XWithIntercept)

	// Compute (X^T * y)
	var XTy mat.VecDense
	XTy.MulVec(XWithIntercept.T(), ymat)

	// Solve for beta (coefficients)
	var beta mat.VecDense
	err := beta.SolveVec(&XT, &XTy)
	if err != nil {
		log.Fatal(err)
	}

	// Print the coefficients
	fmt.Printf("Coefficients: %v\n", mat.Formatted(&beta, mat.Prefix("             "), mat.Squeeze()))
}
// Out:
// Coefficients: ⎡  12.537097419536728⎤
//              ⎢ 0.40869494110716387⎥
//              ⎢-0.21431649816529333⎥
//              ⎢-0.09737403641504794⎥
//              ⎢  0.6476661883408436⎥
//              ⎢ -0.8911282337266179⎥
//              ⎣0.006035263591470038⎦

// %%
import (
    "github.com/sjwhitworth/golearn/base"
    "github.com/sjwhitworth/golearn/linear_model"
    )

func main(){
    dataGrid := base.ConvertDataFrameToInstances(df, 0)
    // Create a linear regression model
    model := linear_models.NewLinearRegression()

    // Fit the model to the data
    err = model.Fit(dataGrid)
    if err != nil {
        // Handle error
        return
    }
    
    
}
// Out:
// <style>
// .gonb-err-location {
// 	background: var(--jp-err-color2);
// 	border-radius: 3px;
// 	border-style: dotted;
// 	border-width: 1px;
// 	border-color: var(--jp-border-color2);
// }
// .gonb-err-location:hover {
// 	border-width: 2px;
// 	border-style: solid;
// 	border-color: var(--jp-border-color2);
// }
// .gonb-err-context {
// 	display: none;
// }
// .gonb-err-location:hover + .gonb-err-context {
// 	background: var(--jp-dialog-background);
// 	border-radius: 3px;
// 	border-style: solid;
// 	border-width: 1px;
// 	border-color: var(--jp-border-color2);
// 	display: block;
// 	white-space: pre;
// 	font-family: monospace;
// }
// .gonb-err-line {
// 	border-radius: 3px;
// 	border-style: dotted;
// 	border-width: 1px;
// 	border-color: var(--jp-border-color2);
// 	background-color: var(--jp-rendermime-err-background);
// 	font-weight: bold;
// }
// .gonb-cell-line-info {
// 	background: var(--jp-layout-color2);
// 	color: #999;
// 	margin: 0.1em;
// 	border: 1px solid var(--jp-border-color1);
// 	padding-left: 0.2em;
// 	padding-right: 0.2em;
// }
// </style>
// <div class="lm-Widget p-Widget lm-Panel p-Panel jp-OutputArea-child">
// <div class="lm-Widget p-Widget jp-RenderedText jp-mod-trusted jp-OutputArea-output" data-mime-type="application/vnd.jupyter.stderr" style="font-family: monospace;">
//
//
// <span style="white-space: pre;"> # github.com/sjwhitworth/golearn/linear_models</span>
//
// <br/>
//
//
// <span style="white-space: pre;"> /opt/go/pkg/mod/github.com/sjwhitworth/golearn@v0.0.0-20221228163002-74ae077eafb2/linear_models/logistic.go:10:9: undefined: Parameter</span>
//
// <br/>
//
//
// <span style="white-space: pre;"> /opt/go/pkg/mod/github.com/sjwhitworth/golearn@v0.0.0-20221228163002-74ae077eafb2/linear_models/logistic.go:11:9: undefined: Model</span>
//
// <br/>
//
//
// <span style="white-space: pre;"> /opt/go/pkg/mod/github.com/sjwhitworth/golearn@v0.0.0-20221228163002-74ae077eafb2/linear_models/logistic.go:17:17: undefined: L2R_LR</span>
//
// <br/>
//
//
// <span style="white-space: pre;"> /opt/go/pkg/mod/github.com/sjwhitworth/golearn@v0.0.0-20221228163002-74ae077eafb2/linear_models/logistic.go:19:17: undefined: L1R_LR</span>
//
// <br/>
//
//
// <span style="white-space: pre;"> /opt/go/pkg/mod/github.com/sjwhitworth/golearn@v0.0.0-20221228163002-74ae077eafb2/linear_models/logistic.go:25:13: undefined: NewParameter</span>
//
// <br/>
//
//
// <span style="white-space: pre;"> /opt/go/pkg/mod/github.com/sjwhitworth/golearn@v0.0.0-20221228163002-74ae077eafb2/linear_models/logistic.go:33:10: undefined: NewProblem</span>
//
// <br/>
//
//
// <span style="white-space: pre;"> /opt/go/pkg/mod/github.com/sjwhitworth/golearn@v0.0.0-20221228163002-74ae077eafb2/linear_models/logistic.go:34:13: undefined: Train</span>
//
// <br/>
//
//
// <span style="white-space: pre;"> /opt/go/pkg/mod/github.com/sjwhitworth/golearn@v0.0.0-20221228163002-74ae077eafb2/linear_models/logistic.go:58:10: undefined: Predict</span>
//
// <br/>
//
//
// <span style="white-space: pre;"> </span>
//
// <br/>
//
// </div>
// failed to run "/usr/local/go/bin/go build -o /tmp/gonb_8fe8148f/gonb_8fe8148f": exit status 1
